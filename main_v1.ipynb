# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import warnings
from tensorflow import keras
import os
import cv2
import pandas as pd
from keras.src.layers import Rescaling
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns

warnings.filterwarnings('ignore')

Sequential = keras.models.Sequential
Conv2D = keras.layers.Conv2D
Flatten = keras.layers.Flatten
Dropout = keras.layers.Dropout
MaxPooling2D = keras.layers.MaxPooling2D
Dense = keras.layers.Dense
Input = keras.layers.Input
EarlyStopping = keras.callbacks.EarlyStopping
ReduceLROnPlateau = keras.callbacks.ReduceLROnPlateau
Layers = keras.layers
ImageDataGenerator = keras.preprocessing.image.ImageDataGenerator
BatchNormalization = keras.layers.BatchNormalization
CSVLogger = keras.callbacks.CSVLogger

# %%
train_path = 'data/training/train'
test_path = 'data/testing/test'
pred_path = 'data/prediction'
PLOT_SAVE_DIR = 'output/plot/v3/'
LOG_DIR = 'output/log/v3/'
MODEL_SAVE_PATH = 'output/model/v3/cnn_model_v3.keras'

IMAGE_SIZE = (150, 150)
BATCH_SIZE = 32
EPOCHS = 100

train_files = []
train_labels = []

test_files = []
test_labels = []

# %%
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator()

# %%
train_ds = train_datagen.flow_from_directory(
    train_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=True
)

test_ds = test_datagen.flow_from_directory(
    test_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %%
for label in os.listdir(train_path):
    label_path = os.path.join(train_path, label)
    if os.path.isdir(label_path):
        for filename in os.listdir(label_path):
            train_files.append(filename)
            train_labels.append(label)

# %%
df_train_files = pd.DataFrame({
    "file": train_files,
    "label": train_labels
})

df_train_files.head()
# Out:
#         file   label
# 0   5109.jpg  forest
# 1  14621.jpg  forest
# 2   6366.jpg  forest
# 3   4565.jpg  forest
# 4  17472.jpg  forest

# %%
class_train_names = df_train_files["label"].unique().tolist()
print(class_train_names)
# Out:
# ['forest', 'buildings', 'glacier', 'street', 'mountain', 'sea']

# %%
for label in os.listdir(test_path):
    label_path = os.path.join(test_path, label)
    if os.path.isdir(label_path):
        for filename in os.listdir(label_path):
            test_files.append(filename)
            test_labels.append(label)

# %%
df_test_files = pd.DataFrame({
    "file": test_files,
    "label": test_labels
})

df_test_files.head()
# Out:
#         file   label
# 0  23933.jpg  forest
# 1  23728.jpg  forest
# 2  24047.jpg  forest
# 3  23700.jpg  forest
# 4  24251.jpg  forest

# %%
class_test_names = df_test_files["label"].unique().tolist()
print(class_train_names)
# Out:
# ['forest', 'buildings', 'glacier', 'street', 'mountain', 'sea']

# %%
def image_path(path):
    image_names = []
    for dirname, _, filenames in os.walk(path):
        for filename in filenames:
            fullpath = os.path.join(dirname, filename)
            image_names.append(fullpath)
    return image_names


images_paths = image_path(pred_path)
len(images_paths)
# Out:
# 7301

# %%
df_train_files = df_train_files.sample(frac=1).reset_index(drop=True)

plt.figure(figsize=(10, 10))

for i in range(15):
    if i >= len(df_train_files):
        break

    file_name = df_train_files.iloc[i]["file"]
    label = df_train_files.iloc[i]["label"]

    image_path = os.path.join(train_path, label, file_name)

    if not os.path.exists(image_path):
        print(f"File not found: {image_path}")
        continue

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Failed to read image: {image_path}")
        continue

    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image, cmap="gray")
    plt.title(label)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
df_test_files = df_test_files.sample(frac=1).reset_index(drop=True)

plt.figure(figsize=(10, 10))

for i in range(15):
    if i >= len(df_train_files):
        break

    file_name = df_test_files.iloc[i]["file"]
    label = df_test_files.iloc[i]["label"]

    image_path = os.path.join(test_path, label, file_name)

    if not os.path.exists(image_path):
        print(f"File not found: {image_path}")
        continue

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Failed to read image: {image_path}")
        continue

    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image, cmap="gray")
    plt.title(label)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
train_class_counts = {}
for class_name in os.listdir(train_path):
    class_dir = os.path.join(train_path, class_name)
    if os.path.isdir(class_dir):
        num_images = len(os.listdir(class_dir))
        train_class_counts[class_name] = num_images
for class_name, count in train_class_counts.items():
    print(f"{class_name}: {count} images")
# Out:
# forest: 2271 images
# buildings: 2191 images
# glacier: 2404 images
# street: 2382 images
# mountain: 2512 images
# sea: 2274 images

# %%
plt.figure(figsize=(10, 6))
plt.bar(train_class_counts.keys(), train_class_counts.values(), color='gray')
plt.title('Image Count Train Per Class')
plt.xlabel('Class Names')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.show()

# %%
test_class_counts = {}
for class_name in os.listdir(test_path):
    class_dir = os.path.join(test_path, class_name)
    if os.path.isdir(class_dir):
        num_images = len(os.listdir(class_dir))
        test_class_counts[class_name] = num_images
for class_name, count in test_class_counts.items():
    print(f"{class_name}: {count} images")
# Out:
# forest: 474 images
# buildings: 437 images
# glacier: 553 images
# street: 501 images
# mountain: 525 images
# sea: 510 images

# %%
plt.figure(figsize=(10, 6))
plt.bar(test_class_counts.keys(), test_class_counts.values(), color='gray')
plt.title('Image Count Test Per Class')
plt.xlabel('Class Names')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.show()

# %%
# Model architecture
model = Sequential()

# Normalization
model.add(Rescaling(1. / 255, input_shape=(150, 150, 1)))

# Convolutional layers 
model.add(Conv2D(32, kernel_size=(5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, kernel_size=(5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

# Flatten and dense layers with Dropout
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.4))

# Output layer
model.add(Dense(units=len(class_train_names), activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_4 (Rescaling)         │ (None, 150, 150, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 146, 146, 32)   │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 146, 146, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 73, 73, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 69, 69, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 69, 69, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 34, 34, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 14, 14, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 14, 14, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │     6,423,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,912,518 (26.37 MB)
#  Trainable params: 6,911,558 (26.37 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=3, min_lr=1e-6),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    CSVLogger(os.path.join(LOG_DIR, 'training_log_v3.csv'), append=True)
]

# Train model
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# Save Model
model.save(MODEL_SAVE_PATH)
# Out:
# Epoch 1/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 259s 586ms/step - accuracy: 0.3582 - loss: 2.5535 - val_accuracy: 0.3777 - val_loss: 1.7448 - learning_rate: 0.0010
# Epoch 2/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 250s 569ms/step - accuracy: 0.4692 - loss: 1.3040 - val_accuracy: 0.3613 - val_loss: 1.5200 - learning_rate: 0.0010
# Epoch 3/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 245s 557ms/step - accuracy: 0.5307 - loss: 1.1826 - val_accuracy: 0.6147 - val_loss: 0.9553 - learning_rate: 0.0010
# Epoch 4/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 245s 557ms/step - accuracy: 0.5828 - loss: 1.0703 - val_accuracy: 0.6857 - val_loss: 0.8962 - learning_rate: 0.0010
# Epoch 5/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 245s 559ms/step - accuracy: 0.6283 - loss: 0.9839 - val_accuracy: 0.1687 - val_loss: 11.4057 - learning_rate: 0.0010
# Epoch 6/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 248s 564ms/step - accuracy: 0.6756 - loss: 0.9030 - val_accuracy: 0.4050 - val_loss: 2.1659 - learning_rate: 0.0010
# Epoch 7/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 250s 569ms/step - accuracy: 0.7071 - loss: 0.8197 - val_accuracy: 0.5720 - val_loss: 1.1670 - learning_rate: 0.0010
# Epoch 8/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 254s 579ms/step - accuracy: 0.7343 - loss: 0.7489 - val_accuracy: 0.7797 - val_loss: 0.6035 - learning_rate: 8.0000e-04
# Epoch 9/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 255s 580ms/step - accuracy: 0.7517 - loss: 0.7132 - val_accuracy: 0.6110 - val_loss: 1.5694 - learning_rate: 8.0000e-04
# Epoch 10/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 253s 577ms/step - accuracy: 0.7701 - loss: 0.6840 - val_accuracy: 0.8000 - val_loss: 0.5692 - learning_rate: 8.0000e-04
# Epoch 11/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 255s 581ms/step - accuracy: 0.7823 - loss: 0.6388 - val_accuracy: 0.8243 - val_loss: 0.5448 - learning_rate: 8.0000e-04
# Epoch 12/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 255s 580ms/step - accuracy: 0.7780 - loss: 0.6502 - val_accuracy: 0.8070 - val_loss: 0.5462 - learning_rate: 8.0000e-04
# Epoch 13/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 255s 580ms/step - accuracy: 0.7883 - loss: 0.6269 - val_accuracy: 0.7967 - val_loss: 0.5899 - learning_rate: 8.0000e-04
# Epoch 14/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 254s 580ms/step - accuracy: 0.8022 - loss: 0.5617 - val_accuracy: 0.7990 - val_loss: 0.5492 - learning_rate: 8.0000e-04
# Epoch 15/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 254s 578ms/step - accuracy: 0.8121 - loss: 0.5588 - val_accuracy: 0.7340 - val_loss: 0.8183 - learning_rate: 6.4000e-04
# Epoch 16/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 254s 579ms/step - accuracy: 0.8292 - loss: 0.5029 - val_accuracy: 0.8007 - val_loss: 0.5844 - learning_rate: 6.4000e-04
# Epoch 17/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 254s 579ms/step - accuracy: 0.8325 - loss: 0.4904 - val_accuracy: 0.7893 - val_loss: 0.6508 - learning_rate: 6.4000e-04
# Epoch 18/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 256s 582ms/step - accuracy: 0.8381 - loss: 0.4787 - val_accuracy: 0.6997 - val_loss: 1.0314 - learning_rate: 5.1200e-04
# Epoch 19/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 255s 580ms/step - accuracy: 0.8457 - loss: 0.4498 - val_accuracy: 0.8397 - val_loss: 0.4878 - learning_rate: 5.1200e-04
# Epoch 20/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 256s 582ms/step - accuracy: 0.8447 - loss: 0.4426 - val_accuracy: 0.8017 - val_loss: 0.5465 - learning_rate: 5.1200e-04
# Epoch 21/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 256s 583ms/step - accuracy: 0.8455 - loss: 0.4461 - val_accuracy: 0.7160 - val_loss: 0.8978 - learning_rate: 5.1200e-04
# Epoch 22/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 257s 585ms/step - accuracy: 0.8528 - loss: 0.4219 - val_accuracy: 0.8303 - val_loss: 0.4974 - learning_rate: 5.1200e-04
# Epoch 23/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 278s 634ms/step - accuracy: 0.8609 - loss: 0.4114 - val_accuracy: 0.8450 - val_loss: 0.4815 - learning_rate: 4.0960e-04
# Epoch 24/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 265s 603ms/step - accuracy: 0.8668 - loss: 0.3828 - val_accuracy: 0.5910 - val_loss: 2.7253 - learning_rate: 4.0960e-04
# Epoch 25/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 257s 586ms/step - accuracy: 0.8744 - loss: 0.3628 - val_accuracy: 0.7593 - val_loss: 0.8892 - learning_rate: 4.0960e-04
# Epoch 26/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 257s 586ms/step - accuracy: 0.8682 - loss: 0.3760 - val_accuracy: 0.8243 - val_loss: 0.6177 - learning_rate: 4.0960e-04
# Epoch 27/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 256s 582ms/step - accuracy: 0.8800 - loss: 0.3480 - val_accuracy: 0.8377 - val_loss: 0.4529 - learning_rate: 3.2768e-04
# Epoch 28/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 261s 595ms/step - accuracy: 0.8856 - loss: 0.3268 - val_accuracy: 0.8380 - val_loss: 0.4943 - learning_rate: 3.2768e-04
# Epoch 29/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 259s 591ms/step - accuracy: 0.8817 - loss: 0.3446 - val_accuracy: 0.7320 - val_loss: 0.9210 - learning_rate: 3.2768e-04
# Epoch 30/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 258s 587ms/step - accuracy: 0.8811 - loss: 0.3444 - val_accuracy: 0.8073 - val_loss: 0.6783 - learning_rate: 3.2768e-04
# Epoch 31/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 258s 587ms/step - accuracy: 0.8933 - loss: 0.2991 - val_accuracy: 0.8673 - val_loss: 0.4126 - learning_rate: 2.6214e-04
# Epoch 32/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 258s 588ms/step - accuracy: 0.8893 - loss: 0.3040 - val_accuracy: 0.8673 - val_loss: 0.4065 - learning_rate: 2.6214e-04
# Epoch 33/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 256s 582ms/step - accuracy: 0.8885 - loss: 0.3094 - val_accuracy: 0.8393 - val_loss: 0.4891 - learning_rate: 2.6214e-04
# Epoch 34/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 254s 579ms/step - accuracy: 0.8887 - loss: 0.3109 - val_accuracy: 0.8350 - val_loss: 0.4702 - learning_rate: 2.6214e-04
# Epoch 35/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 253s 576ms/step - accuracy: 0.8933 - loss: 0.3043 - val_accuracy: 0.8580 - val_loss: 0.4780 - learning_rate: 2.6214e-04
# Epoch 36/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 251s 573ms/step - accuracy: 0.9014 - loss: 0.2724 - val_accuracy: 0.8500 - val_loss: 0.4837 - learning_rate: 2.0972e-04
# Epoch 37/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 251s 572ms/step - accuracy: 0.9048 - loss: 0.2747 - val_accuracy: 0.7973 - val_loss: 0.7036 - learning_rate: 2.0972e-04
# Epoch 38/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 252s 573ms/step - accuracy: 0.9016 - loss: 0.2826 - val_accuracy: 0.8620 - val_loss: 0.4274 - learning_rate: 2.0972e-04
# Epoch 39/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 250s 569ms/step - accuracy: 0.9010 - loss: 0.2854 - val_accuracy: 0.8253 - val_loss: 0.5738 - learning_rate: 1.6777e-04
# Epoch 40/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 251s 571ms/step - accuracy: 0.9103 - loss: 0.2536 - val_accuracy: 0.8620 - val_loss: 0.4361 - learning_rate: 1.6777e-04
# Epoch 41/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 249s 568ms/step - accuracy: 0.9092 - loss: 0.2543 - val_accuracy: 0.8653 - val_loss: 0.4391 - learning_rate: 1.6777e-04
# Epoch 42/100
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 250s 569ms/step - accuracy: 0.9153 - loss: 0.2454 - val_accuracy: 0.8710 - val_loss: 0.4417 - learning_rate: 1.3422e-04

# %%
# Evaluation and Report
test_loss, test_accuracy = model.evaluate(test_ds)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 11s 119ms/step - accuracy: 0.8583 - loss: 0.4305
# Test accuracy: 86.73%

# %%
# Evaluate the model on the training dataset
train_loss, train_accuracy = model.evaluate(train_ds)
print(f'Train accuracy: {train_accuracy * 100:.2f}%')
# Out:
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 54s 123ms/step - accuracy: 0.9029 - loss: 0.2578
# Train accuracy: 90.31%

# %%
# Classification Report and Confusion Matrix
y_true = test_ds.classes
y_pred = np.argmax(model.predict(test_ds), axis=1)
print(classification_report(y_true, y_pred, target_names=test_ds.class_indices.keys()))
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step
#               precision    recall  f1-score   support
#
#    buildings       0.13      0.13      0.13       437
#       forest       0.16      0.16      0.16       474
#      glacier       0.17      0.20      0.18       553
#     mountain       0.19      0.16      0.17       525
#          sea       0.15      0.15      0.15       510
#       street       0.15      0.15      0.15       501
#
#     accuracy                           0.16      3000
#    macro avg       0.16      0.16      0.16      3000
# weighted avg       0.16      0.16      0.16      3000

# %%
# Confusion Matrix Plot
conf_mat = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="Blues", xticklabels=test_ds.class_indices.keys(),
            yticklabels=test_ds.class_indices.keys())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.savefig(os.path.join(PLOT_SAVE_DIR, "confusion_matrix_v3.png"))
plt.show()

# %%
# Plotting Loss and Accuracy
def plot_metrics(history, metric, val_metric, title, y_label, save_path):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history[metric], label="Training")
    plt.plot(history.history[val_metric], label="Validation")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel(y_label)
    plt.legend()
    plt.grid(True)
    plt.savefig(save_path, format="png", dpi=300)
    plt.show()

# %%
plot_metrics(history, 'loss', 'val_loss', "Training and Validation Loss", "Loss",
             os.path.join(PLOT_SAVE_DIR, "training_validation_loss_v3.png"))
plot_metrics(history, 'accuracy', 'val_accuracy', "Training and Validation Accuracy", "Accuracy",
             os.path.join(PLOT_SAVE_DIR, "training_validation_accuracy_v3.png"))

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Binarize the true labels for ROC curve (one-hot encoding)
y_true_bin = label_binarize(y_true, classes=list(range(len(test_ds.class_indices))))

# Get model probabilities
y_pred_prob = model.predict(test_ds)

# Plot ROC curve for each class
plt.figure(figsize=(12, 8))
for i, class_name in enumerate(test_ds.class_indices.keys()):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid()
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 11s 118ms/step
